# %%
import PyPDF2,os,sys,joblib
# import textract
from nltk.util import ngrams
from collections import Counter
from prettytable import PrettyTable
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer('[A-Za-z0-9-]*\w+')
import textract, re
import pdfminer
import pandas as pd
import shutil
from nltk.tokenize import sent_tokenize

# %%
def lowercase(text):
    return text.lower()

def get_file_paragraphs(file_name, fig_no):
    pdfFileObj = open(file_name, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    num_pages = pdfReader.numPages
    full_text = ""
    fig = lowercase(fig_no.split(' ')[0])
    fig_value = fig_no.split(' ')[1]
#     print(num_pages)
    for i in range(4, num_pages):
#         print('page:',i)
        pageObj = pdfReader.getPage(i)
        try:
            page_text = lowercase(pageObj.extractText())
            sentences = sent_tokenize(page_text)
#             if(i==20):
#                 print(sentences)
            para = ''
            before =5
            after = 8
            for i in range(len(sentences)):
                j=i-1
                if((sentences[i][-4:]=='fig.' or sentences[i][-5:]=='fig .' or sentences[i][-5:]=='figs.' or sentences[i][-6:]=='figs .') and (fig_value in sentences[i+1][:4])):
#                     print('yes')
                    if(i-before < 0):
                        stop = -1
                    else:
                        stop = i-before
                    for j in range(i-1, stop, -1):
                        para = sentences[j] + para

                    para += sentences[i]

                    if(i+after >= len(sentences)):
                        stop = len(sentences)
                    else:
                        stop = i+after+1
                    for j in range(i+1, stop, +1):
                        para = para + sentences[j]
            full_text+=para
        except:
            pass
        
    pdfFileObj.close()
    return full_text

# %%
code_xl = pd.read_excel(r'../input/input_1.xlsx')
records = code_xl.values
# records

# %%
data = {}
for row in records:
    patent_id = row[1]
    fig_id = row[2]
    tumor_cell = row[3]
    chemo_agent_virus = row[4]
    y_value = row[5]
    x_value = row[6]
    
    if(patent_id not in data):
        data[patent_id]={}
    if(fig_id not in data[patent_id]):
        data[patent_id][fig_id]={'chemo/virus':[chemo_agent_virus],
                                'tumor/cell_survival':[tumor_cell],# 0 or 1
                                'days':[x_value],
                                'tumor_size_value/cell_survival_value':[y_value],
                                'para':"",
                                'experiment_type':"",
                                'species':"",
                                "cancer_type":"",
                                "cell_lines":[],
                                "quantity":""}      
    else:
        data[patent_id][fig_id]['chemo/virus'].append(chemo_agent_virus)
        data[patent_id][fig_id]['tumor/cell_survival'].append(tumor_cell)
        data[patent_id][fig_id]['days'].append(x_value)
        data[patent_id][fig_id]['tumor_size_value/cell_survival_value'].append(y_value)
#         data[patent_id][fig_id]['para'].append()

# %%
for patent_id in data:
    for key in data[patent_id]: # key is fig_id
#         print(patent_id, key)
        path = r'E:\Sem3\Capstone Project\Google_Patents_PDF_Files_2'
        file_path = os.path.join(path,patent_id)
        information = get_file_paragraphs(file_path,key)
        data[patent_id][key]['para']=information
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]

# %%
def get_experiment_type(paragraph, tumor_cell_survival_list): #invivo or invitro
    
    if(('invivo' in paragraph) or ('in vivo' in paragraph) or ('inject' in paragraph)):
        return "in vivo"
    elif(('invitro' in paragraph) or ('in vitro' in paragraph)):
        return "in vitro"
    else:
        exp_type = sum(tumor_cell_survival_list)
        if(exp_type==0):
            return "in vivo"
        else:
            return "in vitro"
        
def get_species(paragraph,exp_type,invivolist):
    if(exp_type=='in vivo'):
        for animal in invivolist:
            if(animal in paragraph):
                return animal
    else:
        return ''

# %%
def get_cancer_list(cancer_list_file):
    cancers = open(cancer_list_file, 'r').read().lower().split(", ")
    size_based_canc_list = [list() for j in range(4)]
    for cancer in cancers:
        c = lemmatizer.lemmatize(cancer)
        size_based_canc_list[len(c.split(" ")) - 1].append(c)
    return size_based_canc_list


def get_cancer_type(paragraph, caner_list):
    possible_cancers=[]
    for n_gram_list in caner_list:
        for gram in n_gram_list:
            possible_cancers.append((paragraph.count(gram),gram))
    possible_cancers.sort()
    return possible_cancers[-1][1]

def get_cell_lines(paragraph,all_cell_lines):
    temp_1=[]
    temp_2=[]
    for cell_line in all_cell_lines:
        if(cell_line[0] in paragraph):
            if(cell_line[0] not in temp_1 and len(cell_line[0])>2):
                temp_1.append(cell_line[0])
                temp_2.append(cell_line)
    return temp_2

def get_ngrams_tokens(tokens_list, n):
    grams = []
    for ngram in ngrams(tokens_list, n):
        grams.append(' '.join(i for i in ngram))
    return grams

def num_there(s):
    return any(i.isdigit() for i in s)

def get_quantity(paragraph,quantity_list_unigram):
    
    result=""
    tokens = tokenizer.tokenize(paragraph)
    
    unigram = get_ngrams_tokens(tokens,1)
    for quantity in quantity_list_unigram:
        for i in range(len(unigram)):
            if(quantity in unigram[i]):
                x = unigram[i-1]
                if(num_there(x)):
                    if(quantity=='multiplicity' and unigram[i+1]=='of'):
                        result = unigram[i-1] + ' '+unigram[i] + ' '+ unigram[i+1]+ ' '+unigram[i+2]
                    else:
                        result = unigram[i-1]+ ' '+unigram[i]
                    
                elif(num_there(unigram[i])):
                    result = unigram[i]
            if(unigram[i]=='moi' and len(result)==0):
                if(unigram[i+1]=='of' and num_there(unigram[i+2])):
                    result = unigram[i] + ' '+ unigram[i+1]+ ' '+unigram[i+2]
    return result

# %%
invivo_animals = ['scid mice', 'mice', 'mouse', 'rabbit', 'rat', 'dog', 'goat', 'sheep', 'pig', 'cat', 'primate']
all_cell_lines = joblib.load('all_cell_lines.sav')
canc_list = get_cancer_list("cancer list.txt") ## get names of all types of cancers (total 176 types), 
quantity_list_uni=['vp', 'vp/mm', 'moi', 'micromolar', 'multiplicity','pfu', 'tcid']

for patent_id in data:
    for key in data[patent_id]: # key is fig_id
#         print(patent_id, key)
        paragraph = data[patent_id][key]['para']
        tumor_cell_survival_list = data[patent_id][key]['tumor/cell_survival']
        data[patent_id][key]['experiment_type'] = get_experiment_type(paragraph,tumor_cell_survival_list)
        
        exp_type = data[patent_id][key]['experiment_type']
        data[patent_id][key]['species'] = get_species(paragraph,exp_type,invivo_animals)
        data[patent_id][key]['cancer_type'] = get_cancer_type(paragraph,canc_list)
        data[patent_id][key]['cell_lines'] = get_cell_lines(paragraph,all_cell_lines)
        data[patent_id][key]['quantity'] = get_quantity(paragraph,quantity_list_uni)

# %%
data[patent_id][key]
# Out:
# {'chemo/virus': ['CF33-control', 'CF33-rMV-SLAMblind'],
#  'tumor/cell_survival': [0, 0],
#  'days': [50.0, 50.0],
#  'tumor_size_value/cell_survival_value': [600, 100],
#  'para': '11 shows the antitumor effects of rmv - slamblind rmv - slamblind ( n = 8 ) or medium ( n = 8 ) was further and rmv - v ( - ) - slamblind on xenograft models trans - administered at a time point of 6 days after the initial planted with a triple - negative breast cancer cell line .the administration ( day 0 ) .fig .17 ( b ) shows the weight of a volume of a tumor in which the subcutaneously adminis - tumor collected on the 50th day after the initial viral tered hcc70 had grown ( tumor volume ) was measured .30 value = sd of the experimental values .1x10 tcids , of fig .11 shows the antitumor effects of rmv - slamblind rmv - slamblind ( n = 8 ) or medium ( n = 8 ) was further and rmv - v ( - ) - slamblind on xenograft models trans - administered at a time point of 6 days after the initial planted with a triple - negative breast cancer cell line .the administration ( day 0 ) .points of 1 dpi , 3 dpi , 5 dpi , 7 dpi and 9 dpi according to a fig .17 shows the antitumor effects of rmv - slamblind wst - 1 assay .fig .10 ( b ) shows the results obtained by 25 on xenograft models transplanted with a dog breast cancer measuring the viability of the control cells b95a that did not cell line .triple - negative breast cancer cells were 20 rmv - egfp - slamblind , and the viability was then mea infected with rmv - egfp - slamblind and rmv - v ( - ) sured at time points of 1 dpi , 3 dpi , 5 dpi and 7 dpi according egfp - slamblind .fig .10 ( a ) : the viability of the triple - to a wst - 1 assay .viability : survival rate ; and dpi : days post negative breast cancer cells hcc70 was measured at time first inoculation .points of 1 dpi , 3 dpi , 5 dpi , 7 dpi and 9 dpi according to a fig .17 shows the antitumor effects of rmv - slamblind wst - 1 assay .fig .10 ( b ) shows the results obtained by 25 on xenograft models transplanted with a dog breast cancer measuring the viability of the control cells b95a that did not cell line .fig .17 ( a ) : the volume of a tumor , in which a dog express pvrl4 .the numerical value is shown as a mean breast cancer - derived cell line cf33 subcutaneously trans value + sd of the values obtained from three times of experi planted into an immunodeficient mouse had grown , was ments .viability : survival rate ; and dpi : days post first measured .the numerical value is shown as a mean inoculation .fig .17 ( a ) : the volume of a tumor , in which a dog express pvrl4 .the numerical value is shown as a mean breast cancer - derived cell line cf33 subcutaneously trans value + sd of the values obtained from three times of experi planted into an immunodeficient mouse had grown , was ments .viability : survival rate ; and dpi : days post first measured .the numerical value is shown as a mean inoculation .30 value = sd of the experimental values .1x10 tcids , of fig .11 shows the antitumor effects of rmv - slamblind rmv - slamblind ( n = 8 ) or medium ( n = 8 ) was further and rmv - v ( - ) - slamblind on xenograft models trans - administered at a time point of 6 days after the initial planted with a triple - negative breast cancer cell line .the administration ( day 0 ) .fig .17 ( b ) shows the weight of a volume of a tumor in which the subcutaneously adminis - tumor collected on the 50th day after the initial viral tered hcc70 had grown ( tumor volume ) was measured .35 administration in the experiment of fig .17 ( a ) .the numeri the numerical value is shown as a mean value sd of the cal value is shown as a mean value sd of the experimental experimental values .1x10 ﬁ tcids , of mv - slamblind , values .rmv - v ( - ) - slamblind or medium ( control ) was further fig .18 shows the expression states of pvrl4 on the administered at time points of 7 days and 17 days after the surface of human pancreatic cancer cells .fig .35 administration in the experiment of fig .17 ( a ) .the numeri the numerical value is shown as a mean value sd of the cal value is shown as a mean value sd of the experimental experimental value ...
#  'experiment_type': 'in vivo',
#  'species': 'scid mice',
#  'cancer_type': 'breast cancer',
#  'cell_lines': [['klm1', 'pancreas ', 'human'],
#   ['hcc70', 'breast ', 'human'],
#   ['pk1', 'pancreas ', 'human'],
#   ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#   ['mon', 'soft tissue ', 'human'],
#   ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#   ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#   ['cf33', 'breast', ' dog']],
#  'quantity': '1x10 tcids'}

# %%
joblib.dump(data,'data.sav')
# Out:
# ['data.sav']

# %%
# umor_cell_survival_list = data[patent_id][key]['tumor/cell_survival']
# data[patent_id][key]['experiment_type'] = get_experiment_type(paragraph,tumor_cell_survival_list)

# exp_type = data[patent_id][key]['experiment_type']
# data[patent_id][key]['species'] = get_species(paragraph,exp_type,invivo_animals)
# data[patent_id][key]['cancer_type'] = get_cancer_type(paragraph,canc_list)
# data[patent_id][key]['cell_lines'] = get_cell_lines(paragraph,all_cell_lines)
# data[patent_id][key]['quantity'] = get_quantity(paragraph,quantity_list_uni)

# %%
"""
patent_id, cancer type, chemo agent/ oncolytic virus, quantity, tumor volume, cell survival %, days, species, experiment type, cell lines
"""
result=[]
for patent_id in data:
    for fig in data[patent_id]:
        rows = len(data[patent_id][fig]['tumor/cell_survival'])
        for i in range(rows):
            row = []
            row.append(patent_id)
            row.append(data[patent_id][fig]['cancer_type'])
            row.append(data[patent_id][fig]['chemo/virus'][i])
            row.append(data[patent_id][fig]['quantity'])
            if data[patent_id][fig]['tumor/cell_survival'][i] == 0: #tumor
                row.append('')
                row.append(data[patent_id][fig]['tumor_size_value/cell_survival_value'][i])                
            else: # cell survival
                row.append(data[patent_id][fig]['tumor_size_value/cell_survival_value'][i])
                row.append('')
            row.append(data[patent_id][fig]['days'][i])
            row.append(data[patent_id][fig]['species'])
            row.append(data[patent_id][fig]['experiment_type'])
            row.append(data[patent_id][fig]['cell_lines'])
            result.append(row)

# %%
len(result)
# Out:
# 80

# %%
result
# Out:
# [['US5728379.pdf',
#   'brain tumor',
#   'G207-1',
#   '0 moi',
#   0,
#   '',
#   4.0,
#   '',
#   'in vitro',
#   [['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5728379.pdf',
#   'brain tumor',
#   'G207-2',
#   '0 moi',
#   0,
#   '',
#   6.0,
#   '',
#   'in vitro',
#   [['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5728379.pdf',
#   'brain tumor',
#   'Control',
#   '10 pfu',
#   '',
#   '9x',
#   4.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5728379.pdf',
#   'brain tumor',
#   'G207-1',
#   '10 pfu',
#   '',
#   'x',
#   4.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5728379.pdf',
#   'brain tumor',
#   'G207-2',
#   '10 pfu',
#   '',
#   '2x',
#   6.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US9687515.pdf',
#   'womb cancer',
#   'Control',
#   '107 pfu',
#   '',
#   2300,
#   nan,
#   'mice',
#   'in vivo',
#   [['ten', 'endometrium ', 'human'],
#    ['lovo', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mpro', 'bone', ' Mus musculus']]],
#  ['US9687515.pdf',
#   'womb cancer',
#   '5-FC',
#   '107 pfu',
#   '',
#   2200,
#   nan,
#   'mice',
#   'in vivo',
#   [['ten', 'endometrium ', 'human'],
#    ['lovo', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mpro', 'bone', ' Mus musculus']]],
#  ['US9687515.pdf',
#   'womb cancer',
#   'VVTK-I4L-/FCU1',
#   '107 pfu',
#   '',
#   1250,
#   nan,
#   'mice',
#   'in vivo',
#   [['ten', 'endometrium ', 'human'],
#    ['lovo', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mpro', 'bone', ' Mus musculus']]],
#  ['US9687515.pdf',
#   'womb cancer',
#   'VVTK-I4L-/FCU1 + 5-FC',
#   '107 pfu',
#   '',
#   900,
#   nan,
#   'mice',
#   'in vivo',
#   [['ten', 'endometrium ', 'human'],
#    ['lovo', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mpro', 'bone', ' Mus musculus']]],
#  ['US6139834.pdf',
#   'brain tumor',
#   'G207-1',
#   '01 moi',
#   0,
#   '',
#   5.0,
#   'mice',
#   'in vivo',
#   [['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US6139834.pdf',
#   'brain tumor',
#   'G207-2',
#   '01 moi',
#   0,
#   '',
#   6.0,
#   'mice',
#   'in vivo',
#   [['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US6139834.pdf',
#   'womb cancer',
#   'G207-1',
#   '',
#   '',
#   'x',
#   4.0,
#   None,
#   'in vivo',
#   []],
#  ['US6139834.pdf',
#   'womb cancer',
#   'G207-2',
#   '',
#   '',
#   '2x',
#   4.0,
#   None,
#   'in vivo',
#   []],
#  ['US6139834.pdf',
#   'womb cancer',
#   'control',
#   '',
#   '',
#   '8x',
#   6.0,
#   None,
#   'in vivo',
#   []],
#  ['US6428968.pdf',
#   'womb cancer',
#   'Control',
#   '4x10 pful',
#   '',
#   1200,
#   24.0,
#   'scid mice',
#   'in vivo',
#   [['h460', 'Non-Small Cell Lung', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human']]],
#  ['US6428968.pdf',
#   'womb cancer',
#   '1716 only',
#   '4x10 pful',
#   '',
#   1600,
#   24.0,
#   'scid mice',
#   'in vivo',
#   [['h460', 'Non-Small Cell Lung', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human']]],
#  ['US6428968.pdf',
#   'womb cancer',
#   'MMC only',
#   '4x10 pful',
#   '',
#   850,
#   24.0,
#   'scid mice',
#   'in vivo',
#   [['h460', 'Non-Small Cell Lung', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human']]],
#  ['US6428968.pdf',
#   'womb cancer',
#   'MMC + 1716',
#   '4x10 pful',
#   '',
#   500,
#   24.0,
#   'scid mice',
#   'in vivo',
#   [['h460', 'Non-Small Cell Lung', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human']]],
#  ['US7655459.pdf',
#   'womb cancer',
#   'Mock + PBS',
#   '',
#   '',
#   4000,
#   17.0,
#   'mice',
#   'in vivo',
#   [['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['neuro2a', 'brain', ' Mus musculus']]],
#  ['US7655459.pdf',
#   'womb cancer',
#   'Mock + IL-18',
#   '',
#   '',
#   4000,
#   17.0,
#   'mice',
#   'in vivo',
#   [['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['neuro2a', 'brain', ' Mus musculus']]],
#  ['US7655459.pdf',
#   'womb cancer',
#   'G47 + PBS',
#   '',
#   '',
#   2500,
#   17.0,
#   'mice',
#   'in vivo',
#   [['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['neuro2a', 'brain', ' Mus musculus']]],
#  ['US7655459.pdf',
#   'womb cancer',
#   'G47 + IL-18',
#   '',
#   '',
#   500,
#   17.0,
#   'mice',
#   'in vivo',
#   [['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['neuro2a', 'brain', ' Mus musculus']]],
#  ['US7964187.pdf',
#   'womb cancer',
#   'Control',
#   '5x10 pfus',
#   '',
#   95,
#   16.0,
#   'rat',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['c3h', 'embryo', ' Mus musculus']]],
#  ['US7964187.pdf',
#   'womb cancer',
#   'Cisplatin alone',
#   '5x10 pfus',
#   '',
#   118,
#   20.0,
#   'rat',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['c3h', 'embryo', ' Mus musculus']]],
#  ['US7964187.pdf',
#   'womb cancer',
#   'Reovirus alone',
#   '5x10 pfus',
#   '',
#   68,
#   24.0,
#   'rat',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['c3h', 'embryo', ' Mus musculus']]],
#  ['US7964187.pdf',
#   'womb cancer',
#   'Cisplatin + Reovirus',
#   '5x10 pfus',
#   '',
#   25,
#   24.0,
#   'rat',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['c3h', 'embryo', ' Mus musculus']]],
#  ['US9410129.pdf',
#   'pancreatic cancer',
#   'Mock',
#   '1x10 vp',
#   '',
#   21,
#   30.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['skov3', 'ovary ', 'human'],
#    ['gct', 'soft tissue ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['hapt-1', 'blood', ' homo sapiens']]],
#  ['US9410129.pdf',
#   'pancreatic cancer',
#   'ICOVIR -15-GMCSF',
#   '1x10 vp',
#   '',
#   0,
#   23.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['skov3', 'ovary ', 'human'],
#    ['gct', 'soft tissue ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['hapt-1', 'blood', ' homo sapiens']]],
#  ['US9410129.pdf',
#   'pancreatic cancer',
#   'CGTG-603',
#   '1x10 vp',
#   '',
#   0,
#   23.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['skov3', 'ovary ', 'human'],
#    ['gct', 'soft tissue ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['hapt-1', 'blood', ' homo sapiens']]],
#  ['US9410129.pdf',
#   'pancreatic cancer',
#   'AD5-D24-RGD',
#   '1x10 vp',
#   '',
#   3,
#   30.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['skov3', 'ovary ', 'human'],
#    ['gct', 'soft tissue ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['hapt-1', 'blood', ' homo sapiens']]],
#  ['US9410129.pdf',
#   'pancreatic cancer',
#   'AD5-D24-RGD-GMCSF',
#   '1x10 vp',
#   '',
#   0,
#   30.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['skov3', 'ovary ', 'human'],
#    ['gct', 'soft tissue ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['hapt-1', 'blood', ' homo sapiens']]],
#  ['US9241998.pdf',
#   'womb cancer',
#   'control',
#   '10 pfu',
#   '',
#   1350,
#   32.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hel', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human']]],
#  ['US9241998.pdf',
#   'womb cancer',
#   'RSV',
#   '10 pfu',
#   '',
#   410,
#   32.0,
#   'mice',
#   'in vivo',
#   [['pc-3', 'Prostate', 'human'],
#    ['hel', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['cess', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human']]],
#  ['US6770274.pdf',
#   'womb cancer',
#   'Control',
#   '10 pfu',
#   '',
#   120,
#   115.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['u87', 'brain', ' homo sapiens']]],
#  ['US6770274.pdf',
#   'womb cancer',
#   'RE6 treated ',
#   '10 pfu',
#   '',
#   80,
#   115.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['u87', 'brain', ' homo sapiens']]],
#  ['US6770274.pdf',
#   'womb cancer',
#   'R3616',
#   '10 pfu',
#   '',
#   50,
#   115.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['ben', 'lung ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['u87', 'brain', ' homo sapiens']]],
#  ['US7270812B2.pdf',
#   'womb cancer',
#   'control ',
#   '',
#   '',
#   4200,
#   10.0,
#   None,
#   'in vivo',
#   []],
#  ['US7270812B2.pdf',
#   'womb cancer',
#   'reovirus ',
#   '',
#   '',
#   3500,
#   12.0,
#   None,
#   'in vivo',
#   []],
#  ['US7270812B2.pdf',
#   'womb cancer',
#   'Sinbis virus treatment ',
#   '',
#   '',
#   2000,
#   12.0,
#   None,
#   'in vivo',
#   []],
#  ['US7374752.pdf',
#   'womb cancer',
#   'live reovirus',
#   '0x10 pfus',
#   '',
#   200,
#   22.0,
#   'scid mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['c3h', 'embryo', ' Mus musculus']]],
#  ['US7374752.pdf',
#   'womb cancer',
#   'dead reovirus',
#   '0x10 pfus',
#   '',
#   1250,
#   22.0,
#   'scid mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['c3h', 'embryo', ' Mus musculus']]],
#  ['US7393527.pdf',
#   'myeloma',
#   'UV-MV',
#   '1x107 pfus',
#   '',
#   1000,
#   10.0,
#   'scid mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['dan', 'bone', ' Canis familiaris '],
#    ['arh-77', 'blood', 'Homo sapiens']]],
#  ['US7393527.pdf',
#   'myeloma',
#   'MV-Edm',
#   '1x107 pfus',
#   '',
#   0,
#   37.0,
#   'scid mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human'],
#    ['dan', 'bone', ' Canis familiaris '],
#    ['arh-77', 'blood', 'Homo sapiens']]],
#  ['US7470426.pdf',
#   'carcinoma',
#   'PPMK107',
#   '1x10 pfu',
#   25,
#   '',
#   140.0,
#   'mice',
#   'in vivo',
#   [['sw620', 'large intestine ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['mpro', 'bone', ' Mus musculus'],
#    ['es-2', 'ovary', 'Homo sapiens']]],
#  ['US7470426.pdf',
#   'carcinoma',
#   'control',
#   '1x10 pfu',
#   0,
#   '',
#   40.0,
#   'mice',
#   'in vivo',
#   [['sw620', 'large intestine ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['mpro', 'bone', ' Mus musculus'],
#    ['es-2', 'ovary', 'Homo sapiens']]],
#  ['US7473418.pdf',
#   'womb cancer',
#   'OV945',
#   '4x10 vp',
#   '',
#   800,
#   80.0,
#   'mice',
#   'in vivo',
#   [['a549', 'Non-Small Cell Lung', 'human'],
#    ['253j', 'urinary tract ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['hep3b', 'lung', 'Homo sapiens '],
#    ['don', 'lung', 'Cricetulus griseus']]],
#  ['US7473418.pdf',
#   'womb cancer',
#   'PBS-glycerol',
#   '4x10 vp',
#   '',
#   1100,
#   60.0,
#   'mice',
#   'in vivo',
#   [['a549', 'Non-Small Cell Lung', 'human'],
#    ['253j', 'urinary tract ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['hep3b', 'lung', 'Homo sapiens '],
#    ['don', 'lung', 'Cricetulus griseus']]],
#  ['US7473418.pdf',
#   'womb cancer',
#   'OV945',
#   '4x10 vp',
#   0,
#   '',
#   nan,
#   'mice',
#   'in vivo',
#   [['a549', 'Non-Small Cell Lung', 'human'],
#    ['253j', 'urinary tract ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['hep3b', 'lung', 'Homo sapiens '],
#    ['don', 'lung', 'Cricetulus griseus']]],
#  ['US7473418.pdf',
#   'womb cancer',
#   'PBS-glycerol',
#   '4x10 vp',
#   15,
#   '',
#   nan,
#   'mice',
#   'in vivo',
#   [['a549', 'Non-Small Cell Lung', 'human'],
#    ['253j', 'urinary tract ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['gimen', 'autonomic ganglia ', 'human'],
#    ['hep3b', 'lung', 'Homo sapiens '],
#    ['don', 'lung', 'Cricetulus griseus']]],
#  ['US8105578.pdf',
#   'carcinoma',
#   'PPMK107',
#   '1x10 pfu',
#   25,
#   '',
#   140.0,
#   'mice',
#   'in vivo',
#   [['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['mpro', 'bone', ' Mus musculus'],
#    ['es-2', 'ovary', 'Homo sapiens']]],
#  ['US8105578.pdf',
#   'carcinoma',
#   'Saline',
#   '1x10 pfu',
#   0,
#   '',
#   40.0,
#   'mice',
#   'in vivo',
#   [['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['hey', 'ovary ', 'human'],
#    ['mpro', 'bone', ' Mus musculus'],
#    ['es-2', 'ovary', 'Homo sapiens']]],
#  ['US8450106.pdf',
#   'brain tumor',
#   'rHSVQ',
#   '1x10 pfu',
#   0,
#   '',
#   5.0,
#   'mice',
#   'in vivo',
#   [['ln229', 'central nervous system ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['dan', 'bone', ' Canis familiaris '],
#    ['rba', 'mammary-gland', ' Rattus norvegicus'],
#    ['u87', 'brain', ' homo sapiens']]],
#  ['US8450106.pdf',
#   'brain tumor',
#   'rHSVQvasculo 1',
#   '1x10 pfu',
#   0,
#   '',
#   5.0,
#   'mice',
#   'in vivo',
#   [['ln229', 'central nervous system ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['dan', 'bone', ' Canis familiaris '],
#    ['rba', 'mammary-gland', ' Rattus norvegicus'],
#    ['u87', 'brain', ' homo sapiens']]],
#  ['US8450106.pdf',
#   'brain tumor',
#   'rHSVQvasculo2',
#   '1x10 pfu',
#   0,
#   '',
#   5.0,
#   'mice',
#   'in vivo',
#   [['ln229', 'central nervous system ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['sem', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['dan', 'bone', ' Canis familiaris '],
#    ['rba', 'mammary-gland', ' Rattus norvegicus'],
#    ['u87', 'brain', ' homo sapiens']]],
#  ['US8916176.pdf',
#   'carcinoma',
#   'Mock',
#   '10 pfu',
#   '',
#   3500,
#   83.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hel', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['hela', 'cervix ', 'human'],
#    ['miapaca-2', 'pancreas', 'Homo sapiens'],
#    ['panc-1', 'pancreas/duct', 'Homo sapiens']]],
#  ['US8916176.pdf',
#   'carcinoma',
#   'Del H-1PV',
#   '10 pfu',
#   '',
#   0,
#   83.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hel', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['hela', 'cervix ', 'human'],
#    ['miapaca-2', 'pancreas', 'Homo sapiens'],
#    ['panc-1', 'pancreas/duct', 'Homo sapiens']]],
#  ['US8916176.pdf',
#   'carcinoma',
#   'H-1PV',
#   '10 pfu',
#   '',
#   750,
#   83.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hel', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['hela', 'cervix ', 'human'],
#    ['miapaca-2', 'pancreas', 'Homo sapiens'],
#    ['panc-1', 'pancreas/duct', 'Homo sapiens']]],
#  ['US5585096.pdf',
#   'brain tumor',
#   'G207-1',
#   '0 moi',
#   0,
#   '',
#   5.0,
#   'rat',
#   'in vivo',
#   [['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5585096.pdf',
#   'brain tumor',
#   'G207-2',
#   '0 moi',
#   0,
#   '',
#   4.0,
#   'rat',
#   'in vivo',
#   [['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['sch', 'stomach ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5585096.pdf',
#   'brain tumor',
#   'G207-1',
#   '5x10 pfu',
#   '',
#   'x',
#   6.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5585096.pdf',
#   'brain tumor',
#   'G207-2',
#   '5x10 pfu',
#   '',
#   '2x',
#   6.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US5585096.pdf',
#   'brain tumor',
#   'control',
#   '5x10 pfu',
#   '',
#   '9x',
#   6.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['u-87mg', 'brain', 'Home sapiens']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'Control',
#   '',
#   '',
#   200,
#   25.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'NDV(F3aa)',
#   '',
#   '',
#   50,
#   25.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'NDV(F3aa)-NS1',
#   '',
#   '',
#   50,
#   25.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'Control',
#   '',
#   '',
#   200,
#   22.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'NDV(F3aa)',
#   '',
#   '',
#   0,
#   22.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'NDV(F3aa)-NS1',
#   '',
#   '',
#   0,
#   22.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'Control',
#   '',
#   0,
#   '',
#   120.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'NDV(F3aa)',
#   '',
#   40,
#   '',
#   120.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10035984.pdf',
#   'womb cancer',
#   'NDV(F3aa)-NS1',
#   '',
#   70,
#   '',
#   120.0,
#   'mice',
#   'in vivo',
#   [['hos', 'bone ', 'human'],
#    ['hara', 'lung ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['mino', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mot', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['difi', 'large intestine ', 'human']]],
#  ['US10335481.pdf',
#   'metastatic cancer',
#   'DLD1-control',
#   '',
#   '',
#   1200,
#   20.0,
#   'mice',
#   'in vivo',
#   [['ht29', 'Colon', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['klm1', 'pancreas ', 'human'],
#    ['pk1', 'pancreas ', 'human'],
#    ['rko', 'large intestine ', 'human'],
#    ['dld1', 'large intestine ', 'human'],
#    ['sw48', 'large intestine ', 'human'],
#    ['sw948', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['h441', 'lung', 'Homo sapiens']]],
#  ['US10335481.pdf',
#   'metastatic cancer',
#   'DLD1 - rMV - SLAMblind',
#   '',
#   '',
#   400,
#   20.0,
#   'mice',
#   'in vivo',
#   [['ht29', 'Colon', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['klm1', 'pancreas ', 'human'],
#    ['pk1', 'pancreas ', 'human'],
#    ['rko', 'large intestine ', 'human'],
#    ['dld1', 'large intestine ', 'human'],
#    ['sw48', 'large intestine ', 'human'],
#    ['sw948', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['h441', 'lung', 'Homo sapiens']]],
#  ['US10335481.pdf',
#   'metastatic cancer',
#   'HT29-control',
#   '',
#   '',
#   1400,
#   20.0,
#   'mice',
#   'in vivo',
#   [['ht29', 'Colon', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['klm1', 'pancreas ', 'human'],
#    ['pk1', 'pancreas ', 'human'],
#    ['rko', 'large intestine ', 'human'],
#    ['dld1', 'large intestine ', 'human'],
#    ['sw48', 'large intestine ', 'human'],
#    ['sw948', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['h441', 'lung', 'Homo sapiens']]],
#  ['US10335481.pdf',
#   'metastatic cancer',
#   'HT29 - rMV - SLAMblind',
#   '',
#   '',
#   500,
#   20.0,
#   'mice',
#   'in vivo',
#   [['ht29', 'Colon', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['klm1', 'pancreas ', 'human'],
#    ['pk1', 'pancreas ', 'human'],
#    ['rko', 'large intestine ', 'human'],
#    ['dld1', 'large intestine ', 'human'],
#    ['sw48', 'large intestine ', 'human'],
#    ['sw948', 'large intestine ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['h441', 'lung', 'Homo sapiens']]],
#  ['US10335481.pdf',
#   'breast cancer',
#   'control',
#   '1x100 tcids',
#   '',
#   1000,
#   30.0,
#   '',
#   'in vitro',
#   [['mcf7', 'Breast', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['hcc1187', 'breast ', 'human'],
#    ['hcc70', 'breast ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['cf33', 'breast', ' dog']]],
#  ['US10335481.pdf',
#   'breast cancer',
#   'rMV-SLAMblind',
#   '1x100 tcids',
#   '',
#   300,
#   30.0,
#   '',
#   'in vitro',
#   [['mcf7', 'Breast', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['hcc1187', 'breast ', 'human'],
#    ['hcc70', 'breast ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['cf33', 'breast', ' dog']]],
#  ['US10335481.pdf',
#   'breast cancer',
#   'rMV -V - SLAMblind',
#   '1x100 tcids',
#   '',
#   300,
#   30.0,
#   '',
#   'in vitro',
#   [['mcf7', 'Breast', 'human'],
#    ['hos', 'bone ', 'human'],
#    ['ten', 'endometrium ', 'human'],
#    ['hcc1187', 'breast ', 'human'],
#    ['hcc70', 'breast ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['cf33', 'breast', ' dog']]],
#  ['US10335481.pdf',
#   'breast cancer',
#   'CF33-control',
#   '1x10 tcids',
#   '',
#   600,
#   50.0,
#   'scid mice',
#   'in vivo',
#   [['klm1', 'pancreas ', 'human'],
#    ['hcc70', 'breast ', 'human'],
#    ['pk1', 'pancreas ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['cf33', 'breast', ' dog']]],
#  ['US10335481.pdf',
#   'breast cancer',
#   'CF33-rMV-SLAMblind',
#   '1x10 tcids',
#   '',
#   100,
#   50.0,
#   'scid mice',
#   'in vivo',
#   [['klm1', 'pancreas ', 'human'],
#    ['hcc70', 'breast ', 'human'],
#    ['pk1', 'pancreas ', 'human'],
#    ['del', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['mon', 'soft tissue ', 'human'],
#    ['tur', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['val', 'haematopoietic and lymphoid tissue ', 'human'],
#    ['cf33', 'breast', ' dog']]]]

# %%
pd.DataFrame(data).to_csv('OUTPUT.csv')

# %%
df = pd.DataFrame(result,columns=['patent_id', 'cancer type', 'chemo agent/ oncolytic virus', 'quantity', 'tumor volume', 'cell survival %', 'days', 'species', 'experiment type', 'cell lines']) # transpose to look just like the sheet above
df.to_excel('OUTPUT.xlsx')
